# %%
# merge and rename
import shutil
import os
path = "/msl/home/kelly08385/Pictures/Fast_defect/8800_0307/data"
despath = "/msl/home/kelly08385/Pictures/Fast_defect/8800_0307/JPEGImages"
for root,dirs,files in os.walk(path):
    for file in files:
        #dir = root.split('/')[-1]
        shutil.copy(os.path.join(root,file),os.path.join(os.path.join(despath,file)))
        #os.rename(os.path.join(root,file),os.path.join(despath, dir, file[:-4]+'.jpg'))

# %%
def mkdir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
## use original image and crop image to find xml 

import xml.etree.cElementTree as ET
import cv2
import os
import numpy as np
import shutil

crop_path = "/msl/home/kelly08385/Pictures/Fast_defect/8800/crop"
des_crop_path = "/msl/home/kelly08385/Pictures/Fast_defect/8800/train_crop"
ori_path = "/msl/home/kelly08385/Pictures/Fast_defect/8800/ori"
des_path = "/msl/home/kelly08385/Pictures/Fast_defect/8800/data"
des_path2 = "/msl/home/kelly08385/Pictures/Fast_defect/8800/JPEGImages"
xml_path = "/msl/home/kelly08385/Pictures/Fast_defect/8800/Annotations"

#quiz_path = "/home/kelly/Pictures/defect/0312_work/9300/quiz"

# %%
for root,dirs,files in os.walk(crop_path):
    dir = root.split("/")[-1]
    for file in files:
        mkdir(os.path.join(des_path,dir))
        mkdir(os.path.join(des_crop_path,dir))
        if os.path.exists(os.path.join(ori_path,dir,file[:-4]+".jpg")):

            try:
                cropImg = cv2.imread(os.path.join(root,file))
                cropImg = cv2.cvtColor(cropImg, cv2.COLOR_BGR2GRAY)
                oriImg = cv2.imread(os.path.join(ori_path,dir,file[:-4]+".jpg"))
                oriImg = cv2.cvtColor(oriImg, cv2.COLOR_BGR2GRAY)
                
                result = cv2.matchTemplate(oriImg, cropImg, cv2.TM_CCOEFF_NORMED) 
                x_and_y = np.unravel_index(result.argmax(),result.shape)
                print(x_and_y)

                tree = ET.parse('/msl/home/kelly08385/Pictures/trained_defect/total/Annotations/2300AAHL5AHYC14C100007-03.xml')
                tree_root = tree.getroot()
                print(tree_root)
                change_dict = {"filename":file,"width":oriImg.shape[1],"height":oriImg.shape[0],"xmin":x_and_y[1],"ymin":x_and_y[0],\
                               "xmax":x_and_y[1]+cropImg.shape[1],"ymax":x_and_y[0]+cropImg.shape[0],"name":root.split("/")[-1]}
                for key in change_dict.keys():
                    for e in tree_root.iter(key):
                        e.text = str(change_dict[key])
                shutil.copy(os.path.join(ori_path,dir,file),os.path.join(des_path2,file))
                shutil.move(os.path.join(ori_path,dir,file),os.path.join(des_path,dir,file))
                shutil.move(os.path.join(root,file),os.path.join(des_crop_path,dir,file))
                tree.write(os.path.join(xml_path,file[:-4]+".xml"))
            except:
                print("contunue")
# Out:
# (376, 658)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (536, 659)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (397, 644)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (283, 605)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# (614, 676)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (481, 612)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (355, 611)
# <Element 'annotation' at 0x7f5b3f03d818>
# (363, 667)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# contunue
# (727, 761)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (315, 477)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (389, 451)
# <Element 'annotation' at 0x7f5b3f03d958>
# contunue
# (421, 761)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (553, 490)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (391, 473)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (505, 631)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (426, 683)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (446, 588)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (552, 691)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (315, 581)
# <Element 'annotation' at 0x7f5b3f03df98>
# (503, 547)
# <Element 'annotation' at 0x7f5b3f03d778>
# (524, 611)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (388, 528)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (482, 830)
# <Element 'annotation' at 0x7f5b3f03d138>
# (557, 657)
# <Element 'annotation' at 0x7f5b3f03d638>
# (254, 102)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (242, 854)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (543, 557)
# <Element 'annotation' at 0x7f5b3f03d958>
# contunue
# (467, 443)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (345, 591)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (333, 555)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (557, 832)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (13, 725)
# <Element 'annotation' at 0x7f5b3f03da98>
# contunue
# (439, 574)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (475, 859)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (431, 541)
# <Element 'annotation' at 0x7f5b3f03dae8>
# (526, 792)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# (601, 605)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (394, 797)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (462, 620)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (615, 579)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (553, 593)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# (399, 699)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (661, 719)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (554, 777)
# <Element 'annotation' at 0x7f5b3f03def8>
# (421, 605)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (549, 623)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (538, 672)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (448, 655)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# contunue
# (389, 737)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (348, 563)
# <Element 'annotation' at 0x7f5b3f0a8458>
# contunue
# (309, 573)
# <Element 'annotation' at 0x7f5b3f03d138>
# contunue
# (469, 525)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (398, 575)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (293, 573)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (508, 713)
# <Element 'annotation' at 0x7f5b3f03d958>
# contunue
# (452, 578)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (417, 639)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (489, 693)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (385, 652)
# <Element 'annotation' at 0x7f5b3f03d598>
# (571, 603)
# <Element 'annotation' at 0x7f5b3f03de58>
# contunue
# (490, 257)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (396, 552)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (514, 641)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (594, 729)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (623, 567)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (508, 651)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (293, 623)
# <Element 'annotation' at 0x7f5b3f03d138>
# contunue
# (267, 619)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# contunue
# (453, 693)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (491, 729)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (410, 697)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (424, 553)
# <Element 'annotation' at 0x7f5b3f03d778>
# (419, 621)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (439, 647)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# (428, 478)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (439, 579)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# contunue
# (331, 641)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (408, 550)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (490, 735)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (523, 717)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# contunue
# (380, 699)
# <Element 'annotation' at 0x7f5b3f03d138>
# (380, 625)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (398, 723)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (411, 612)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (530, 574)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (239, 505)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (447, 703)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (279, 671)
# <Element 'annotation' at 0x7f5b3f03d598>
# (494, 516)
# <Element 'annotation' at 0x7f5b3f03d188>
# (0, 0)
# <Element 'annotation' at 0x7f5b3f0a8458>
# contunue
# (345, 700)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (370, 762)
# <Element 'annotation' at 0x7f5b3f03d638>
# (433, 621)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (155, 611)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (493, 599)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (543, 703)
# <Element 'annotation' at 0x7f5b3f03de08>
# (375, 685)
# <Element 'annotation' at 0x7f5b3f03d138>
# (460, 674)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (210, 591)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (360, 780)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# (346, 591)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (375, 689)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (343, 519)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (363, 615)
# <Element 'annotation' at 0x7f5b3f03def8>
# (391, 604)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# contunue
# (402, 641)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (179, 769)
# <Element 'annotation' at 0x7f5b3f0a8958>
# contunue
# (429, 591)
# <Element 'annotation' at 0x7f5b3f03d958>
# (451, 687)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# (0, 0)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (339, 523)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (412, 586)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (507, 629)
# <Element 'annotation' at 0x7f5b3f03d598>
# (375, 679)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (413, 733)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (500, 492)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# (462, 732)
# <Element 'annotation' at 0x7f5b3f03d138>
# (339, 525)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (290, 596)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (365, 784)
# <Element 'annotation' at 0x7f5b3f03d188>
# (431, 710)
# <Element 'annotation' at 0x7f5b3f03da98>
# contunue
# (345, 713)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (511, 619)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (625, 931)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (407, 539)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (465, 655)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (429, 442)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (439, 501)
# <Element 'annotation' at 0x7f5b3f03df48>
# contunue
# (422, 519)
# <Element 'annotation' at 0x7f5b3f03d598>
# (417, 553)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (286, 642)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (470, 498)
# <Element 'annotation' at 0x7f5b3f03de08>
# (347, 519)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (385, 579)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# (331, 616)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (434, 559)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (414, 637)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (335, 407)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (333, 662)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (384, 589)
# <Element 'annotation' at 0x7f5b3f03d958>
# (465, 629)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (539, 613)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (653, 569)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (451, 617)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# contunue
# (533, 765)
# <Element 'annotation' at 0x7f5b3f03d598>
# (344, 727)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (573, 624)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (477, 603)
# <Element 'annotation' at 0x7f5b3f03df48>
# contunue
# (479, 727)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (369, 687)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (340, 547)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (458, 639)
# <Element 'annotation' at 0x7f5b3f03def8>
# (461, 651)
# <Element 'annotation' at 0x7f5b3f03da98>
# contunue
# (275, 705)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (352, 607)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (56, 471)
# <Element 'annotation' at 0x7f5b3f03dae8>
# (342, 790)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# (256, 549)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (649, 587)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (355, 509)
# <Element 'annotation' at 0x7f5b3f03d138>
# contunue
# (25, 259)
# <Element 'annotation' at 0x7f5b3f03dae8>
# (337, 451)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (229, 532)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (527, 615)
# <Element 'annotation' at 0x7f5b3f03def8>
# (425, 673)
# <Element 'annotation' at 0x7f5b3f03d138>
# contunue
# (559, 505)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (215, 683)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (386, 636)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (328, 658)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# (345, 744)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# (481, 611)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (320, 527)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (491, 763)
# <Element 'annotation' at 0x7f5b3f03de08>
# (375, 679)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (307, 675)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (393, 593)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# contunue
# (487, 685)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (487, 568)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (650, 679)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (485, 677)
# <Element 'annotation' at 0x7f5b3f03de58>
# (391, 699)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (427, 469)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (587, 599)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (513, 897)
# <Element 'annotation' at 0x7f5b3f03df48>
# contunue
# (515, 700)
# <Element 'annotation' at 0x7f5b3f03d778>
# (453, 541)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (385, 567)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (439, 758)
# <Element 'annotation' at 0x7f5b3f03de58>
# (315, 801)
# <Element 'annotation' at 0x7f5b3f03d188>
# (385, 637)
# <Element 'annotation' at 0x7f5b3f0a8958>
# contunue
# (488, 628)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (284, 518)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# (393, 639)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (452, 598)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (508, 645)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (347, 657)
# <Element 'annotation' at 0x7f5b3f03d598>
# (667, 678)
# <Element 'annotation' at 0x7f5b3f03da98>
# (472, 700)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (321, 609)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (278, 627)
# <Element 'annotation' at 0x7f5b3f03d138>
# contunue
# (550, 629)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (560, 700)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (205, 505)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (457, 814)
# <Element 'annotation' at 0x7f5b3f03dc28>
# (513, 665)
# <Element 'annotation' at 0x7f5b3f03d138>
# (305, 435)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (375, 653)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (80, 1126)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# (506, 548)
# <Element 'annotation' at 0x7f5b3f03de58>
# (472, 505)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (459, 684)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (595, 676)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# (464, 948)
# <Element 'annotation' at 0x7f5b3f03d958>
# (261, 537)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (337, 523)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (365, 607)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (251, 625)
# <Element 'annotation' at 0x7f5b3f03da98>
# contunue
# (451, 625)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (337, 533)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (418, 587)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (424, 520)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (355, 727)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (548, 506)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (557, 631)
# <Element 'annotation' at 0x7f5b3f03def8>
# (567, 653)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (531, 738)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (655, 659)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (397, 613)
# <Element 'annotation' at 0x7f5b3f03d778>
# contunue
# (431, 507)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (416, 787)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (369, 532)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (361, 671)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (585, 542)
# <Element 'annotation' at 0x7f5b3f03de58>
# (116, 403)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (435, 445)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (449, 737)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# (351, 617)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# contunue
# (390, 643)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (414, 742)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (437, 599)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# contunue
# (507, 609)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (311, 631)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (535, 831)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (418, 562)
# <Element 'annotation' at 0x7f5b3f03de08>
# (359, 732)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# contunue
# (469, 587)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (313, 789)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (349, 355)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (249, 721)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# (389, 595)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (535, 744)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (441, 598)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (401, 578)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# (392, 712)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (310, 698)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (536, 579)
# <Element 'annotation' at 0x7f5b3f03d958>
# (559, 741)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (437, 740)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (533, 806)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (420, 563)
# <Element 'annotation' at 0x7f5b3f03d778>
# (395, 600)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (325, 563)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (448, 612)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (504, 679)
# <Element 'annotation' at 0x7f5b3f03def8>
# (505, 599)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (447, 621)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (450, 686)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (642, 632)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# contunue
# (453, 641)
# <Element 'annotation' at 0x7f5b3f03d598>
# (280, 476)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (484, 472)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (380, 605)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (357, 603)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# contunue
# (545, 614)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (453, 625)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (424, 644)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (327, 729)
# <Element 'annotation' at 0x7f5b3f03de08>
# (549, 706)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (553, 603)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (321, 572)
# <Element 'annotation' at 0x7f5b3f03def8>
# (614, 594)
# <Element 'annotation' at 0x7f5b3f03d638>
# (477, 716)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (286, 727)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (483, 549)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (453, 752)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (397, 573)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (480, 629)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (303, 636)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (295, 645)
# <Element 'annotation' at 0x7f5b3f03df48>
# (369, 519)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (437, 565)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (202, 584)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# contunue
# (487, 432)
# <Element 'annotation' at 0x7f5b3f03dae8>
# (335, 521)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (525, 617)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (332, 642)
# <Element 'annotation' at 0x7f5b3f03dea8>
# (373, 797)
# <Element 'annotation' at 0x7f5b3f03d638>
# (214, 606)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (405, 727)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (533, 575)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (557, 763)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (375, 567)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (409, 687)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (265, 371)
# <Element 'annotation' at 0x7f5b3f03dea8>
# (258, 597)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (499, 581)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (397, 611)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (383, 738)
# <Element 'annotation' at 0x7f5b3f03df48>
# (527, 647)
# <Element 'annotation' at 0x7f5b3f03de58>
# (301, 837)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (535, 678)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (297, 529)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (531, 731)
# <Element 'annotation' at 0x7f5b3f03d778>
# contunue
# (380, 727)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (338, 706)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (567, 612)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (382, 620)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (537, 631)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (332, 597)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (463, 638)
# <Element 'annotation' at 0x7f5b3f03d818>
# (499, 745)
# <Element 'annotation' at 0x7f5b3f03dae8>
# (410, 522)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (468, 627)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (486, 610)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# (383, 649)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (222, 807)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (391, 565)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (339, 427)
# <Element 'annotation' at 0x7f5b3f03d638>
# (826, 857)
# <Element 'annotation' at 0x7f5b3f03d818>
# (436, 763)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (347, 543)
# <Element 'annotation' at 0x7f5b3f0a8958>
# contunue
# (329, 622)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (370, 590)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (516, 578)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (370, 552)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (247, 685)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (120, 875)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (452, 663)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (393, 640)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (484, 718)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (507, 538)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# contunue
# (378, 598)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (323, 625)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (327, 569)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (499, 601)
# <Element 'annotation' at 0x7f5b3f03de58>
# contunue
# (553, 543)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (493, 661)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (572, 564)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (468, 595)
# <Element 'annotation' at 0x7f5b3f03d818>
# (270, 781)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (261, 679)
# <Element 'annotation' at 0x7f5b3f0a8958>
# contunue
# (415, 713)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (421, 1145)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (471, 400)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# (425, 645)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (591, 723)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (414, 598)
# <Element 'annotation' at 0x7f5b3f03d598>
# (514, 689)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (461, 721)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (478, 680)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (493, 522)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# (341, 552)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (311, 439)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (387, 651)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (489, 554)
# <Element 'annotation' at 0x7f5b3f03d958>
# (305, 539)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (409, 711)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (400, 690)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (449, 609)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (485, 594)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (499, 503)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (653, 527)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (341, 565)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (250, 757)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (485, 670)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (583, 567)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (365, 605)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (423, 677)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (649, 663)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (501, 565)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (578, 768)
# <Element 'annotation' at 0x7f5b3f03de08>
# (264, 649)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (362, 598)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (475, 516)
# <Element 'annotation' at 0x7f5b3f03d598>
# (477, 573)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# (672, 840)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (560, 821)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (484, 548)
# <Element 'annotation' at 0x7f5b3f03d598>
# (620, 780)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (363, 607)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (465, 19)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (410, 598)
# <Element 'annotation' at 0x7f5b3f03d958>
# (437, 501)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (591, 442)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (396, 561)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (607, 709)
# <Element 'annotation' at 0x7f5b3f03d638>
# (505, 585)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# contunue
# (532, 625)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (491, 383)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (408, 603)
# <Element 'annotation' at 0x7f5b3f03d958>
# (311, 628)
# <Element 'annotation' at 0x7f5b3f03de08>
# (377, 545)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (481, 679)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (523, 661)
# <Element 'annotation' at 0x7f5b3f03d958>
# contunue
# (346, 377)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (524, 728)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (399, 491)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (446, 675)
# <Element 'annotation' at 0x7f5b3f03dea8>
# (369, 591)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (426, 689)
# <Element 'annotation' at 0x7f5b3f0a8958>
# contunue
# (481, 611)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (369, 446)
# <Element 'annotation' at 0x7f5b3f03dae8>
# (425, 713)
# <Element 'annotation' at 0x7f5b3f03d138>
# contunue
# (455, 538)
# <Element 'annotation' at 0x7f5b3f03d958>
# (418, 644)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (471, 625)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (518, 637)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (361, 688)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (547, 749)
# <Element 'annotation' at 0x7f5b3f03d958>
# contunue
# (689, 654)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (416, 562)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (477, 604)
# <Element 'annotation' at 0x7f5b3f03da98>
# contunue
# (509, 571)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# contunue
# (453, 631)
# <Element 'annotation' at 0x7f5b3f0a8958>
# contunue
# (281, 811)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (433, 601)
# <Element 'annotation' at 0x7f5b3f03d138>
# (441, 578)
# <Element 'annotation' at 0x7f5b3f03d598>
# (459, 663)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (324, 740)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# (515, 683)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# (595, 643)
# <Element 'annotation' at 0x7f5b3f03d138>
# (403, 657)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (392, 628)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (297, 371)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (471, 515)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (483, 666)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (579, 443)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# (452, 660)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (595, 530)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (317, 718)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (463, 703)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (459, 585)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# (419, 614)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (351, 627)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (451, 545)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (451, 501)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# (269, 468)
# <Element 'annotation' at 0x7f5b3f03dc28>
# (732, 700)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (414, 639)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (347, 669)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (539, 723)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (408, 702)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (308, 652)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (389, 938)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (360, 691)
# <Element 'annotation' at 0x7f5b3f03d818>
# (434, 509)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (369, 587)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (437, 563)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (369, 604)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (535, 707)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (472, 537)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (178, 792)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (553, 704)
# <Element 'annotation' at 0x7f5b3f03dae8>
# (430, 534)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (482, 681)
# <Element 'annotation' at 0x7f5b3f0a8818>
# contunue
# (529, 657)
# <Element 'annotation' at 0x7f5b3f03d188>
# (596, 450)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (477, 555)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (526, 732)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (712, 854)
# <Element 'annotation' at 0x7f5b3f03d8b8>
# (597, 775)
# <Element 'annotation' at 0x7f5b3f03def8>
# (155, 667)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (289, 751)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (645, 840)
# <Element 'annotation' at 0x7f5b3f03d638>
# (493, 617)
# <Element 'annotation' at 0x7f5b3f03df48>
# contunue
# (268, 610)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (489, 566)
# <Element 'annotation' at 0x7f5b3f0a8458>
# contunue
# (363, 647)
# <Element 'annotation' at 0x7f5b3f03ddb8>
# (582, 621)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (504, 593)
# <Element 'annotation' at 0x7f5b3f0a8188>
# (433, 597)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (539, 721)
# <Element 'annotation' at 0x7f5b3f03d638>
# (416, 668)
# <Element 'annotation' at 0x7f5b3f03d1d8>
# (257, 659)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (349, 556)
# <Element 'annotation' at 0x7f5b3f0a8958>
# (371, 637)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (417, 699)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# (315, 640)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# (527, 651)
# <Element 'annotation' at 0x7f5b3f0a8458>
# (304, 769)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (341, 699)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (253, 589)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (466, 764)
# <Element 'annotation' at 0x7f5b3f0a8318>
# (364, 629)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (522, 608)
# <Element 'annotation' at 0x7f5b3f03dea8>
# contunue
# (376, 662)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# (394, 615)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (367, 663)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (481, 677)
# <Element 'annotation' at 0x7f5b3f03de58>
# contunue
# (521, 661)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (527, 479)
# <Element 'annotation' at 0x7f5b3f0a8458>
# contunue
# (387, 622)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (523, 705)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (484, 681)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# (565, 636)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (291, 491)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (627, 576)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (553, 521)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# (596, 587)
# <Element 'annotation' at 0x7f5b3f0a8818>
# (127, 499)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (387, 495)
# <Element 'annotation' at 0x7f5b3f03d188>
# (467, 740)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# (435, 538)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (365, 659)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (715, 829)
# <Element 'annotation' at 0x7f5b3f03d6d8>
# contunue
# (413, 490)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# (277, 351)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (451, 497)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (466, 696)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (618, 513)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (483, 694)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (279, 612)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (380, 500)
# <Element 'annotation' at 0x7f5b3f03dc28>
# (253, 864)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (436, 199)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (509, 706)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (313, 537)
# <Element 'annotation' at 0x7f5b3f03def8>
# (520, 616)
# <Element 'annotation' at 0x7f5b3efe8b38>
# (355, 540)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (353, 639)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (486, 502)
# <Element 'annotation' at 0x7f5b3f03df98>
# (536, 690)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (179, 378)
# <Element 'annotation' at 0x7f5b3efe8d18>
# (455, 619)
# <Element 'annotation' at 0x7f5b3f03d638>
# (425, 509)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (508, 549)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# contunue
# (466, 352)
# <Element 'annotation' at 0x7f5b3efe8d68>
# (349, 613)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (280, 585)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (708, 621)
# <Element 'annotation' at 0x7f5b3efe8b38>
# contunue
# (387, 695)
# <Element 'annotation' at 0x7f5b3efe8b88>
# contunue
# (526, 447)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (366, 324)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (665, 460)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (484, 656)
# <Element 'annotation' at 0x7f5b3efe8cc8>
# (494, 536)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (387, 499)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (518, 711)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (387, 381)
# <Element 'annotation' at 0x7f5b3efddf48>
# (370, 829)
# <Element 'annotation' at 0x7f5b3f03dc28>
# (384, 341)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (430, 604)
# <Element 'annotation' at 0x7f5b3efe8728>
# (616, 363)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (376, 558)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (562, 553)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (511, 396)
# <Element 'annotation' at 0x7f5b3efe8c78>
# (279, 598)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (387, 622)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (440, 897)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (13, 618)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (560, 852)
# <Element 'annotation' at 0x7f5b3efe81d8>
# (241, 613)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (422, 364)
# <Element 'annotation' at 0x7f5b3f03de08>
# (504, 458)
# <Element 'annotation' at 0x7f5b3efe80e8>
# (498, 678)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (517, 701)
# <Element 'annotation' at 0x7f5b3f03df98>
# (200, 677)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (75, 821)
# <Element 'annotation' at 0x7f5b3efe8d18>
# contunue
# (300, 587)
# <Element 'annotation' at 0x7f5b3efe8b88>
# contunue
# (291, 321)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (253, 210)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (453, 871)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (483, 802)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (519, 498)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (497, 667)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (401, 549)
# <Element 'annotation' at 0x7f5b3efe8c28>
# (584, 694)
# <Element 'annotation' at 0x7f5b3efe8d18>
# (662, 384)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (280, 655)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (277, 652)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (668, 201)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# contunue
# (397, 481)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (389, 708)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (456, 736)
# <Element 'annotation' at 0x7f5b3efe8138>
# contunue
# (512, 583)
# <Element 'annotation' at 0x7f5b3efe8c28>
# (487, 559)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (186, 591)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (431, 534)
# <Element 'annotation' at 0x7f5b3efe8b38>
# contunue
# (475, 533)
# <Element 'annotation' at 0x7f5b3efe8b88>
# contunue
# (525, 445)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (387, 415)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (439, 660)
# <Element 'annotation' at 0x7f5b3efe8d68>
# contunue
# (716, 448)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (527, 604)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (453, 642)
# <Element 'annotation' at 0x7f5b3f03dc28>
# (681, 466)
# <Element 'annotation' at 0x7f5b3efe80e8>
# contunue
# (290, 635)
# <Element 'annotation' at 0x7f5b3efe8d18>
# contunue
# (387, 604)
# <Element 'annotation' at 0x7f5b3f03df98>
# (316, 658)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (476, 580)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (362, 770)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# (487, 733)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (259, 682)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (655, 392)
# <Element 'annotation' at 0x7f5b3efe81d8>
# contunue
# (501, 551)
# <Element 'annotation' at 0x7f5b3efe8c28>
# (402, 569)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (297, 577)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (521, 707)
# <Element 'annotation' at 0x7f5b3efe8c78>
# (263, 22)
# <Element 'annotation' at 0x7f5b3efe8b88>
# (401, 776)
# <Element 'annotation' at 0x7f5b3f03def8>
# (341, 696)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (261, 799)
# <Element 'annotation' at 0x7f5b3efe8048>
# (381, 737)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (383, 671)
# <Element 'annotation' at 0x7f5b3f03df98>
# (394, 682)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (325, 565)
# <Element 'annotation' at 0x7f5b3efe8138>
# (258, 176)
# <Element 'annotation' at 0x7f5b3efe8d18>
# (773, 427)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (500, 691)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (275, 629)
# <Element 'annotation' at 0x7f5b3efe8d68>
# contunue
# (391, 695)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# contunue
# (413, 512)
# <Element 'annotation' at 0x7f5b3f03df98>
# (158, 471)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (378, 536)
# <Element 'annotation' at 0x7f5b3efe80e8>
# (405, 633)
# <Element 'annotation' at 0x7f5b3efe8c28>
# (339, 553)
# <Element 'annotation' at 0x7f5b3f03def8>
# (313, 780)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (277, 314)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (338, 518)
# <Element 'annotation' at 0x7f5b3efe81d8>
# (503, 704)
# <Element 'annotation' at 0x7f5b3f03df98>
# (358, 684)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (389, 356)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (233, 88)
# <Element 'annotation' at 0x7f5b3efe80e8>
# contunue
# (269, 716)
# <Element 'annotation' at 0x7f5b3f03def8>
# (47, 732)
# <Element 'annotation' at 0x7f5b3efddf48>
# (315, 538)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (569, 891)
# <Element 'annotation' at 0x7f5b3efe8138>
# contunue
# (191, 745)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (539, 805)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (530, 638)
# <Element 'annotation' at 0x7f5b3efe8d18>
# (509, 687)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# (394, 221)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (116, 607)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (629, 450)
# <Element 'annotation' at 0x7f5b3efe8b88>
# contunue
# (353, 701)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (279, 683)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (330, 785)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (435, 564)
# <Element 'annotation' at 0x7f5b3efe8728>
# (228, 509)
# <Element 'annotation' at 0x7f5b3efe81d8>
# contunue
# (454, 258)
# <Element 'annotation' at 0x7f5b3f03df98>
# (152, 623)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (626, 620)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (356, 542)
# <Element 'annotation' at 0x7f5b3efe8098>
# contunue
# (416, 568)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (444, 685)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (575, 355)
# <Element 'annotation' at 0x7f5b3efe8b38>
# (491, 405)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (431, 509)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (352, 71)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (407, 752)
# <Element 'annotation' at 0x7f5b3efe8188>
# contunue
# (490, 524)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (291, 607)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (475, 568)
# <Element 'annotation' at 0x7f5b3f03dc28>
# (497, 509)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (269, 721)
# <Element 'annotation' at 0x7f5b3efe8d18>
# contunue
# (409, 531)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (482, 406)
# <Element 'annotation' at 0x7f5b3f03de08>
# (333, 189)
# <Element 'annotation' at 0x7f5b3efe8db8>
# (208, 630)
# <Element 'annotation' at 0x7f5b3efe8188>
# contunue
# (119, 118)
# <Element 'annotation' at 0x7f5b3f03d638>
# (369, 484)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (430, 500)
# <Element 'annotation' at 0x7f5b3efe8c28>
# contunue
# (311, 530)
# <Element 'annotation' at 0x7f5b3efe81d8>
# contunue
# (656, 570)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (298, 581)
# <Element 'annotation' at 0x7f5b3f03dc28>
# (220, 659)
# <Element 'annotation' at 0x7f5b3efddf48>
# (237, 764)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (468, 944)
# <Element 'annotation' at 0x7f5b3f03df98>
# (332, 209)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (296, 710)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (436, 671)
# <Element 'annotation' at 0x7f5b3efe8c28>
# contunue
# (561, 601)
# <Element 'annotation' at 0x7f5b3f03d638>
# (594, 577)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (424, 735)
# <Element 'annotation' at 0x7f5b3efddf48>
# (363, 586)
# <Element 'annotation' at 0x7f5b3efe80e8>
# (347, 715)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (316, 842)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (731, 573)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# contunue
# (418, 714)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (247, 877)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (260, 728)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (166, 529)
# <Element 'annotation' at 0x7f5b3efe8728>
# (225, 681)
# <Element 'annotation' at 0x7f5b3efe8cc8>
# contunue
# (366, 730)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (437, 474)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (259, 702)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (333, 966)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# (168, 288)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (294, 817)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (403, 470)
# <Element 'annotation' at 0x7f5b3efe8b38>
# contunue
# (297, 573)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (326, 593)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (453, 677)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (360, 583)
# <Element 'annotation' at 0x7f5b3efe8048>
# (286, 578)
# <Element 'annotation' at 0x7f5b3efe8188>
# contunue
# (169, 590)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (676, 627)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# contunue
# (451, 516)
# <Element 'annotation' at 0x7f5b3efddf48>
# (536, 661)
# <Element 'annotation' at 0x7f5b3efe8b38>
# (457, 623)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (495, 555)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (87, 307)
# <Element 'annotation' at 0x7f5b3efe8098>
# (206, 571)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (195, 254)
# <Element 'annotation' at 0x7f5b3f03df98>
# (481, 629)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (369, 570)
# <Element 'annotation' at 0x7f5b3efe81d8>
# contunue
# (456, 547)
# <Element 'annotation' at 0x7f5b3efe8c28>
# contunue
# (350, 775)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (358, 651)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (393, 481)
# <Element 'annotation' at 0x7f5b3efe8d68>
# contunue
# (402, 640)
# <Element 'annotation' at 0x7f5b3efe80e8>
# contunue
# (559, 411)
# <Element 'annotation' at 0x7f5b3f03df98>
# (443, 596)
# <Element 'annotation' at 0x7f5b3f03d638>
# (309, 321)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (160, 650)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (532, 279)
# <Element 'annotation' at 0x7f5b3f03def8>
# (427, 518)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (342, 581)
# <Element 'annotation' at 0x7f5b3efe8d18>
# contunue
# (227, 437)
# <Element 'annotation' at 0x7f5b3efe8d68>
# contunue
# (375, 653)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (413, 671)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (289, 602)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (441, 318)
# <Element 'annotation' at 0x7f5b3efddf48>
# (0, 0)
# <Element 'annotation' at 0x7f5b3f03def8>
# (424, 529)
# <Element 'annotation' at 0x7f5b3f0a8c78>
# contunue
# (330, 542)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# (226, 543)
# <Element 'annotation' at 0x7f5b3efe81d8>
# contunue
# (666, 564)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (304, 513)
# <Element 'annotation' at 0x7f5b3f03d638>
# (448, 577)
# <Element 'annotation' at 0x7f5b3efe8d18>
# (384, 722)
# <Element 'annotation' at 0x7f5b3efe8cc8>
# contunue
# (183, 826)
# <Element 'annotation' at 0x7f5b3f03def8>
# (329, 661)
# <Element 'annotation' at 0x7f5b3f03de08>
# (644, 812)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (502, 381)
# <Element 'annotation' at 0x7f5b3efe8138>
# (472, 2)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (491, 429)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (556, 323)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (258, 537)
# <Element 'annotation' at 0x7f5b3efe8db8>
# (200, 302)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (541, 476)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (370, 681)
# <Element 'annotation' at 0x7f5b3efe8d18>
# contunue
# (213, 839)
# <Element 'annotation' at 0x7f5b3efe8b88>
# (465, 657)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (557, 680)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (559, 606)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (394, 712)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (398, 729)
# <Element 'annotation' at 0x7f5b3f03def8>
# (382, 505)
# <Element 'annotation' at 0x7f5b3f03de08>
# (419, 530)
# <Element 'annotation' at 0x7f5b3efe8728>
# (555, 631)
# <Element 'annotation' at 0x7f5b3efe80e8>
# contunue
# (774, 738)
# <Element 'annotation' at 0x7f5b3f03dd18>
# contunue
# (498, 671)
# <Element 'annotation' at 0x7f5b3f03dbd8>
# (651, 468)
# <Element 'annotation' at 0x7f5b3efddf48>
# (218, 718)
# <Element 'annotation' at 0x7f5b3efe8098>
# (493, 458)
# <Element 'annotation' at 0x7f5b3f03df98>
# (372, 824)
# <Element 'annotation' at 0x7f5b3efddf48>
# contunue
# (397, 546)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (278, 533)
# <Element 'annotation' at 0x7f5b3efe8d68>
# contunue
# (470, 656)
# <Element 'annotation' at 0x7f5b3efddf48>
# (261, 569)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (387, 643)
# <Element 'annotation' at 0x7f5b3efe8c28>
# contunue
# (202, 826)
# <Element 'annotation' at 0x7f5b3efddf48>
# (205, 673)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (239, 623)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (245, 410)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (535, 328)
# <Element 'annotation' at 0x7f5b3efe81d8>
# (429, 742)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (504, 741)
# <Element 'annotation' at 0x7f5b3f03df98>
# (338, 204)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (415, 527)
# <Element 'annotation' at 0x7f5b3efe8cc8>
# contunue
# (476, 683)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (412, 756)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (702, 566)
# <Element 'annotation' at 0x7f5b3efe8c28>
# contunue
# (496, 475)
# <Element 'annotation' at 0x7f5b3efe8188>
# (234, 498)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (212, 771)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (757, 707)
# <Element 'annotation' at 0x7f5b3efe8728>
# contunue
# (77, 426)
# <Element 'annotation' at 0x7f5b3efe8db8>
# (417, 523)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (557, 597)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (485, 627)
# <Element 'annotation' at 0x7f5b3efe8d18>
# contunue
# (231, 586)
# <Element 'annotation' at 0x7f5b3efe80e8>
# (481, 354)
# <Element 'annotation' at 0x7f5b3f03d638>
# (443, 0)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (580, 406)
# <Element 'annotation' at 0x7f5b3efe8048>
# contunue
# (294, 203)
# <Element 'annotation' at 0x7f5b3efe8728>
# (272, 689)
# <Element 'annotation' at 0x7f5b3f03def8>
# (602, 518)
# <Element 'annotation' at 0x7f5b3f03de08>
# contunue
# (187, 620)
# <Element 'annotation' at 0x7f5b3efe8138>
# contunue
# (435, 602)
# <Element 'annotation' at 0x7f5b3efe8b88>
# contunue
# (214, 704)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (450, 799)
# <Element 'annotation' at 0x7f5b3f03df98>
# contunue
# (429, 660)
# <Element 'annotation' at 0x7f5b3efe8d18>
# (262, 769)
# <Element 'annotation' at 0x7f5b3efe8c28>
# contunue
# (235, 704)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (307, 486)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (193, 622)
# <Element 'annotation' at 0x7f5b3efe8048>
# (263, 638)
# <Element 'annotation' at 0x7f5b3efe8bd8>
# (377, 756)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# contunue
# (338, 699)
# <Element 'annotation' at 0x7f5b3f03dd68>
# (328, 36)
# <Element 'annotation' at 0x7f5b3efe8138>
# contunue
# (585, 414)
# <Element 'annotation' at 0x7f5b3efe8b38>
# contunue
# (307, 665)
# <Element 'annotation' at 0x7f5b3efddef8>
# (374, 201)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (283, 0)
# <Element 'annotation' at 0x7f5b3efe8cc8>
# (513, 727)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (461, 133)
# <Element 'annotation' at 0x7f5b3f03def8>
# contunue
# (591, 577)
# <Element 'annotation' at 0x7f5b3f03dc28>
# contunue
# (35, 514)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (401, 193)
# <Element 'annotation' at 0x7f5b3efe8188>
# contunue
# (528, 692)
# <Element 'annotation' at 0x7f5b3f03de08>
# (300, 454)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (495, 464)
# <Element 'annotation' at 0x7f5b3efe8d18>
# contunue
# (245, 561)
# <Element 'annotation' at 0x7f5b3efe8db8>
# contunue
# (747, 613)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (378, 578)
# <Element 'annotation' at 0x7f5b3f03de08>
# (420, 560)
# <Element 'annotation' at 0x7f5b3efe8cc8>
# (342, 799)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (264, 487)
# <Element 'annotation' at 0x7f5b3f03d638>
# contunue
# (568, 505)
# <Element 'annotation' at 0x7f5b3f0a8318>
# contunue
# (315, 783)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (106, 0)
# <Element 'annotation' at 0x7f5b3efe8138>
# (295, 564)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (335, 617)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (144, 193)
# <Element 'annotation' at 0x7f5b3efe8c78>
# contunue
# (359, 616)
# <Element 'annotation' at 0x7f5b3efe8d18>
# (392, 685)
# <Element 'annotation' at 0x7f5b3f03df98>
# (383, 773)
# <Element 'annotation' at 0x7f5b3f03dd18>
# (174, 366)
# <Element 'annotation' at 0x7f5b3efe80e8>
# contunue
# (507, 687)
# <Element 'annotation' at 0x7f5b3efe8d68>
# contunue
# (250, 525)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (619, 514)
# <Element 'annotation' at 0x7f5b3f03dd68>
# contunue
# (436, 290)
# <Element 'annotation' at 0x7f5b3efe8048>
# (358, 659)
# <Element 'annotation' at 0x7f5b3efe80e8>
# contunue
# (413, 684)
# <Element 'annotation' at 0x7f5b3f03d0e8>
# (377, 452)
# <Element 'annotation' at 0x7f5b3efddef8>
# contunue
# (353, 625)
# ...
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (425, 721)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (383, 707)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (131, 565)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (381, 828)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (364, 787)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (381, 525)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (449, 627)
# <Element 'annotation' at 0x7f5b36254e58>
# contunue
# (548, 694)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (390, 483)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (515, 609)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (288, 464)
# <Element 'annotation' at 0x7f5b36254d18>
# contunue
# (137, 516)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (373, 553)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (143, 527)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (408, 649)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (414, 590)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (451, 658)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (325, 470)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (250, 983)
# <Element 'annotation' at 0x7f5b36254cc8>
# contunue
# (456, 538)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (482, 620)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (365, 673)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (515, 593)
# <Element 'annotation' at 0x7f5b36254ef8>
# contunue
# (365, 611)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (320, 747)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (835, 462)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (461, 700)
# <Element 'annotation' at 0x7f5b36254e08>
# contunue
# (485, 494)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (416, 514)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (264, 720)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (223, 535)
# <Element 'annotation' at 0x7f5b362544a8>
# contunue
# (418, 604)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (235, 799)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (332, 622)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (385, 671)
# <Element 'annotation' at 0x7f5b36254e58>
# contunue
# (112, 542)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (337, 601)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (475, 697)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (289, 653)
# <Element 'annotation' at 0x7f5b36254ea8>
# contunue
# (339, 467)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (351, 541)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (623, 745)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (351, 741)
# <Element 'annotation' at 0x7f5b36254cc8>
# contunue
# (618, 631)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (482, 706)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (371, 517)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (685, 408)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (286, 453)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (384, 589)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (543, 367)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (155, 387)
# <Element 'annotation' at 0x7f5b36254e58>
# contunue
# (417, 581)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (451, 567)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (183, 472)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (411, 520)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (360, 545)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (463, 608)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (200, 413)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (393, 796)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (562, 539)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (367, 581)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (432, 713)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (269, 651)
# <Element 'annotation' at 0x7f5b36254e08>
# contunue
# (421, 717)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (358, 698)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (206, 771)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (219, 740)
# <Element 'annotation' at 0x7f5b36254d68>
# (351, 793)
# <Element 'annotation' at 0x7f5b3efb9048>
# (441, 491)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (417, 453)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (367, 725)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (38, 537)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (608, 741)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (147, 445)
# <Element 'annotation' at 0x7f5b3f0a8458>
# contunue
# (727, 528)
# <Element 'annotation' at 0x7f5b36254e58>
# contunue
# (340, 567)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (31, 618)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (415, 593)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (287, 598)
# <Element 'annotation' at 0x7f5b36254db8>
# contunue
# (250, 405)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (243, 677)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (387, 589)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# (95, 535)
# <Element 'annotation' at 0x7f5b362544a8>
# contunue
# (345, 558)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (163, 563)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (122, 611)
# <Element 'annotation' at 0x7f5b36254cc8>
# (217, 535)
# <Element 'annotation' at 0x7f5b36254f48>
# contunue
# (381, 700)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (295, 641)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (87, 567)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (226, 436)
# <Element 'annotation' at 0x7f5b36254d18>
# contunue
# (449, 569)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (484, 585)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (414, 484)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (395, 450)
# <Element 'annotation' at 0x7f5b36254f98>
# contunue
# (312, 620)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (283, 406)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (443, 439)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (425, 481)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (535, 415)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (328, 706)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (335, 710)
# <Element 'annotation' at 0x7f5b3f0a8458>
# contunue
# (481, 643)
# <Element 'annotation' at 0x7f5b36254ea8>
# contunue
# (401, 469)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (27, 590)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (490, 806)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (319, 619)
# <Element 'annotation' at 0x7f5b36254f98>
# contunue
# (193, 585)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (453, 507)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (744, 449)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (462, 538)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (405, 429)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (535, 701)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (389, 763)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (252, 589)
# <Element 'annotation' at 0x7f5b36254db8>
# contunue
# (301, 555)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (327, 419)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (300, 542)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (347, 659)
# <Element 'annotation' at 0x7f5b36254f98>
# contunue
# (348, 567)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (453, 447)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (380, 439)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (443, 671)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (453, 488)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (185, 463)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (343, 465)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (270, 709)
# <Element 'annotation' at 0x7f5b36254d68>
# contunue
# (225, 479)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (438, 630)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (399, 454)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (239, 565)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (386, 206)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (413, 605)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (369, 537)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (219, 607)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (251, 657)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (371, 439)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (250, 536)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (247, 502)
# <Element 'annotation' at 0x7f5b362544a8>
# contunue
# (343, 579)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (225, 665)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (299, 714)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# (434, 551)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (273, 513)
# <Element 'annotation' at 0x7f5b3efb9048>
# contunue
# (308, 534)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (403, 709)
# <Element 'annotation' at 0x7f5b3f0a83b8>
# contunue
# (281, 597)
# <Element 'annotation' at 0x7f5b36254e08>
# contunue
# (642, 485)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (230, 621)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (385, 517)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (307, 435)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (291, 469)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (486, 703)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (554, 169)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (405, 659)
# <Element 'annotation' at 0x7f5b36254ea8>
# contunue
# (480, 734)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (591, 531)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (438, 804)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (387, 521)
# <Element 'annotation' at 0x7f5b36254d68>
# contunue
# (516, 476)
# <Element 'annotation' at 0x7f5b3efb9048>
# contunue
# (446, 702)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (620, 635)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (400, 590)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (446, 743)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (796, 344)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (365, 534)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (269, 603)
# <Element 'annotation' at 0x7f5b36254db8>
# contunue
# (253, 663)
# <Element 'annotation' at 0x7f5b3efb9048>
# contunue
# (255, 582)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (341, 621)
# <Element 'annotation' at 0x7f5b3f0a8458>
# contunue
# (151, 645)
# <Element 'annotation' at 0x7f5b36254cc8>
# contunue
# (505, 607)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (314, 681)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (460, 714)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (391, 761)
# <Element 'annotation' at 0x7f5b36254d68>
# contunue
# (635, 744)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (336, 569)
# <Element 'annotation' at 0x7f5b3f03d598>
# (253, 717)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (468, 618)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (614, 225)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (301, 609)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (1, 756)
# <Element 'annotation' at 0x7f5b3f0a8ae8>
# contunue
# (387, 499)
# <Element 'annotation' at 0x7f5b36254d18>
# contunue
# (433, 617)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (322, 648)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (506, 601)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (3, 409)
# <Element 'annotation' at 0x7f5b36254db8>
# contunue
# (116, 548)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (291, 575)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (353, 496)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (309, 553)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (195, 491)
# <Element 'annotation' at 0x7f5b3efb9048>
# contunue
# (327, 539)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (327, 674)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (191, 509)
# <Element 'annotation' at 0x7f5b362544a8>
# contunue
# (411, 679)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (264, 543)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (447, 623)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (335, 511)
# <Element 'annotation' at 0x7f5b36254cc8>
# contunue
# (482, 431)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (121, 470)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (348, 522)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (424, 606)
# <Element 'annotation' at 0x7f5b36254ef8>
# contunue
# (417, 655)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (369, 625)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (306, 505)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (185, 536)
# <Element 'annotation' at 0x7f5b36254ea8>
# contunue
# (51, 487)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (332, 546)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (1, 682)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (341, 710)
# <Element 'annotation' at 0x7f5b36254d18>
# contunue
# (271, 519)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (467, 625)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (483, 585)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (525, 547)
# <Element 'annotation' at 0x7f5b36254ef8>
# contunue
# (450, 623)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (271, 637)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (369, 621)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (683, 400)
# <Element 'annotation' at 0x7f5b36254d68>
# (337, 571)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (303, 679)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (313, 355)
# <Element 'annotation' at 0x7f5b3f0a8bd8>
# contunue
# (397, 699)
# <Element 'annotation' at 0x7f5b36254e58>
# contunue
# (279, 741)
# <Element 'annotation' at 0x7f5b3efb91d8>
# contunue
# (385, 581)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (302, 550)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (262, 669)
# <Element 'annotation' at 0x7f5b36254cc8>
# contunue
# (419, 473)
# <Element 'annotation' at 0x7f5b3efb9278>
# contunue
# (293, 800)
# <Element 'annotation' at 0x7f5b3f03d188>
# (315, 656)
# <Element 'annotation' at 0x7f5b3f0a8db8>
# contunue
# (288, 595)
# <Element 'annotation' at 0x7f5b36254e08>
# contunue
# (167, 588)
# <Element 'annotation' at 0x7f5b3efb9048>
# contunue
# (437, 691)
# <Element 'annotation' at 0x7f5b3f03d188>
# contunue
# (401, 569)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (243, 598)
# <Element 'annotation' at 0x7f5b3f0a8e58>
# contunue
# (398, 523)
# <Element 'annotation' at 0x7f5b3efb91d8>
# (287, 508)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (275, 624)
# <Element 'annotation' at 0x7f5b3f0a8f98>
# contunue
# (170, 350)
# <Element 'annotation' at 0x7f5b362544a8>
# contunue
# (267, 1155)
# <Element 'annotation' at 0x7f5b3efb9278>
# (28, 535)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (363, 526)
# <Element 'annotation' at 0x7f5b3f03d598>
# contunue
# (446, 699)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (288, 592)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (220, 592)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (305, 550)
# <Element 'annotation' at 0x7f5b3f0a8188>
# contunue
# (404, 505)
# <Element 'annotation' at 0x7f5b36254f98>
# contunue
# (658, 537)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (423, 605)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (467, 714)
# <Element 'annotation' at 0x7f5b3f03d818>
# contunue
# (425, 732)
# <Element 'annotation' at 0x7f5b36254ef8>
# contunue
# (107, 507)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (312, 693)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (352, 608)
# <Element 'annotation' at 0x7f5b3f0a8ef8>
# contunue
# (443, 565)
# <Element 'annotation' at 0x7f5b36254ea8>
# contunue
# (529, 647)
# <Element 'annotation' at 0x7f5b3efb9138>
# contunue
# (252, 590)
# <Element 'annotation' at 0x7f5b3f03d9a8>
# contunue
# (498, 742)
# <Element 'annotation' at 0x7f5b3f0a8d18>
# contunue
# (483, 636)
# <Element 'annotation' at 0x7f5b36254d68>
# contunue
# (465, 670)
# <Element 'annotation' at 0x7f5b3efb9188>
# contunue
# (361, 637)
# <Element 'annotation' at 0x7f5b3f03dae8>
# contunue
# (261, 599)
# <Element 'annotation' at 0x7f5b3f0a84f8>
# contunue
# (443, 689)
# <Element 'annotation' at 0x7f5b36254f98>
# contunue

# %%
# use xml to catch picture
ori_path = "/home/kelly/Pictures/defect/0322_work/4800/no_rec"
crop_path = "/home/kelly/Pictures/defect/0322_work/4800/rec"
xml_path = "/home/kelly/Pictures/fastrcnn/4800_0323/result/Annotations"
des_path = "/home/kelly/Pictures/fastrcnn/4800_0323/data"

for root,dirs,files in os.walk(crop_path):
    for file in files:
        dir = root.split('/')[-1]
        print(os.path.join(ori_path,dir,file[:-4]+".jpg"))
        print(os.path.join(xml_path,file[:-4]+".xml"))
        desPath = os.path.join(des_path,dir)
        print(desPath)
#         if os.path.exists(os.path.join(ori_path,dir,file[:-4]+".jpg")) and\
#                           os.path.exists(os.path.join(xml_path,file[:-4]+".xml")):
#             mkdir(desPath)
#             shutil.move(os.path.join(ori_path,dir,file[:-4]+".jpg"),os.path.join(des_path,dir,file[:-4]+".jpg"))

# %% [markdown]
# # Use A little train size to do faster RCNN

# %%
# use picture to catch xml
import shutil 
pic_path = "/home/kelly/Pictures/fastrcnn/8800_0307/data"
xml_path = "/home/kelly/Pictures/defect/0307_work/xml"
des_xml_path = "/home/kelly/Pictures/fastrcnn/8800_0307/result/Annotations"

for root, dirs,files in os.walk(pic_path):
    for file in files:
        shutil.copy(os.path.join(xml_path,file[:-4]+".xml"),os.path.join(des_xml_path,file[:-4]+".xml"))

# %%
# select the untrain image 
import shutil
original_pic_path = "/home/kelly/Pictures/fastrcnn/8800_0124/picture"
trained_pic_path = "/home/kelly/Pictures/fastrcnn/8800_0302_100/result2/data"
des_path = "/home/kelly/Pictures/fastrcnn/8800_0302_100/result2/demo"

for root, dirs, files in os.walk(original_pic_path):
    for file in files:
        dir = root.split("/")[-1]
        dir_path = os.path.join(trained_pic_path,dir)
        if not os.path.exists(os.path.join(des_path,dir)):
            os.mkdir(os.path.join(des_path,dir))
        trained_file = os.listdir(dir_path)
        if not os.path.exists(os.path.join(des_path,dir)):
            os.mkdir(os.path.join(des_path,dir))
        if not file in trained_file:
            shutil.copy(os.path.join(root,file),os.path.join(des_path,dir,file))

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %%
# find red rec
from scipy.misc import imread, imsave
import numpy as np
from skimage.segmentation import clear_border
from skimage.measure import regionprops, label

def size(a, b=0, nargout=1):
    s = np.asarray(a).shape
    if s is ():
        return 1 if b else (1,)*nargout
    # a is not a scalar
    try:
        if b:
            return s[b-1]
        elif nargout > 1:
            return s
    except Exception:
        return 1
    return  1
 
def im2double(im):
    info = np.iinfo(im.dtype)
    return im.astype(np.float) / info.max

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

def double(img):
    return img.astype(np.float)

def getImgInRedRect(imgPath):
        ret = ''
        path_arr = imgPath.split(os.path.sep)
        rawImg = imread(imgPath)
        if size(rawImg,3) < 3:
            return ret
#         output = os.path.abspath(os.path.join(targetPath,'redRec'))
#         for index, path_ in enumerate(path_arr):
#             if path_ not in sourcePath.split(os.path.sep):
#                 output = os.path.join(output, path_)
 
        tmpImg = np.copy(rawImg)
        tmpImg = im2double(tmpImg)
        tmpImg[:,:,0] = tmpImg[:,:,0] > 0.8
        tmpImg[:,:,1] = tmpImg[:,:,1] < 0.2
        tmpImg[:,:,2] = tmpImg[:,:,2] < 0.2
        tmpImg = rgb2gray(tmpImg)
        tmpImg = double(tmpImg > 0.8)
        bw = tmpImg > 0.8
        bw = bw.astype(int)
        cleared = clear_border(bw)
        stats = regionprops(label(cleared))
        flag = False
        #print (imgPath)
        #print(output, output2, output3)
        for currentStats in stats:
            minr, minc, maxr, maxc = currentStats.bbox
            if currentStats.area > 1000 and (maxr-minr) > 25 and (maxc-minc) > 25: # red rectangle
                x = int(max(round(minr + 10), 1))
                y = int(min(round(maxc - 10), size(rawImg,2)))
                crop = rawImg[x:int(min(round(maxr - 10), size(rawImg,1))), int(max(round(minc + 10) , 1)):y,:]
                flag = True
                returnX = x
                returnY = int(max(round(minc + 10) , 1))
                #imsave(output, crop)
        if flag:
            return crop
        else:
            return None
                #print ("red rec:", output)

# %%
# run the faster rcnn demo
import cv2,os,shutil
import xml.etree.cElementTree as ET


# use demooutput to find xml
# use rec to find no rec

def create_xml(ori_path,root,file,xml_path,data_path,des_rec):
    
    imgPath = os.path.join(root,file)
    ori_path = os.path.join(ori_path,root.split('/')[-1])
    # 原圖不存在
    if not os.path.exists(os.path.join(ori_path,file[:-4]+".jpg")):
        return
    oriImg = cv2.imread(os.path.join(ori_path,file[:-4]+".jpg"))
    oriImg = cv2.cvtColor(oriImg, cv2.COLOR_BGR2GRAY)
        
    #xml_path = os.path.join(xml_path,root.split('/')[-1])
    data_path = os.path.join(data_path,root.split('/')[-1])
    des_rec_path = os.path.join(des_rec,root.split('/')[-1])
    mkdir(des_rec_path)
    mkdir(data_path)

    cropImg = getImgInRedRect(imgPath)
    
    if not cropImg is None :
        cropImg = cv2.cvtColor(cropImg, cv2.COLOR_BGR2GRAY)
        oriImg.astype(np.uint8)
        #print(cropImg)
        #cropImg = cropImg[:,:,:-1]
        #print(cropImg)
        result = cv2.matchTemplate(oriImg, cropImg, cv2.TM_CCOEFF_NORMED) 
        x_and_y = np.unravel_index(result.argmax(),result.shape)
        print(x_and_y)

        tree = ET.parse('/msl/home/kelly08385/Pictures/trained_defect/total/Annotations/2300AAHL5AHYC14C100007-03.xml')
        tree_root = tree.getroot()
        change_dict = {"filename":"2300AAHL5AHYC14C100007-03.xml","width":oriImg.shape[1],"height":oriImg.shape[0],"xmin":x_and_y[1],"ymin":x_and_y[0],\
                                       "xmax":x_and_y[1]+cropImg.shape[1],"ymax":x_and_y[0]+cropImg.shape[0],"name":root.split('/')[-1]}

        for key in change_dict.keys():
            for e in tree_root.iter(key):
                e.text = str(change_dict[key])
                tree.write(os.path.join(xml_path,file[:-4]+".xml"))
        shutil.move(os.path.join(ori_path,file),os.path.join(data_path,file))
        shutil.move(imgPath,os.path.join(des_rec_path,file))

# %%
# use demooutput to create xml
# use rec to find no rec



ori_path = "/msl/home/kelly08385/Pictures/Fast_defect/4300/ori"
rec_path = "/msl/home/kelly08385/Pictures/Fast_defect/4300/rec"
xml_path = "/msl/home/kelly08385/Pictures/Fast_defect/4300/Annotations"
data_path = "/msl/home/kelly08385/Pictures/Fast_defect/4300/data"
des_rec = "/msl/home/kelly08385/Pictures/Fast_defect/4300/train_rec"

for root, dirs, files in os.walk(rec_path):
    for file in files:
        print(file)
        create_xml(ori_path,root,file,xml_path,data_path,des_rec)
# Out:
# 4300TL83M1RAZ155100011-01.jpg
# 4300TL83U3KAT11L100003-01.jpg
# 4300TL83N0TAR1B5100012-01.jpg
# 4300TL83P0EAE1BH100021-01.jpg
# 4300TL83T54AM14A100015-01.jpg
# 4300TL7CE4JAA161100009-01.jpg
# 4300TL83T4BAK1AD100014-01.jpg
# 4300TL83R35AE15B100012-01.jpg
# 4300TL83M1RAZ171100015-01.jpg
# 4300TL83Q0DAD182100014-01.jpg
# 4300TL83H1WAA148100004-01.jpg
# 4300TL83S0EAN14D100009-01.jpg
# 4300TL77N0AAQ192100006-01.jpg
# 4300TL83N1TAA157100013-01.jpg
# 4300TL83S18AH196100020-01.jpg
# 4300TL83K0YAK152100012-01.jpg
# 4300TL83H1LAG19G100017-01.jpg
# 4300TL83S0LAE149100008-01.jpg
# 4300TL83J2FAB161100012-01.jpg
# 4300TL83R1PAG18A100016-01.jpg
# 4300TL83P0HAZ1BJ100028-01.jpg
# 4300TL77N0AAV192100007-01.jpg
# 4300TL83E2HBB12D100008-01.jpg
# 4300TL83M0JAU1AF100021-01.jpg
# 4300TL83J0YAR153100014-01.jpg
# 4300TL83J1AAV13D100007-01.jpg
# 4300TL83T2AAG128100016-01.jpg
# 4300TL83H1MAH111100003-01.jpg
# 4300TL83Q16BB1A1100017-01.jpg
# 4300TL83R15AR14L100010-01.jpg
# 4300TL83K11BD191100015-01.jpg
# 4300TL83Q4SAU105100010-01.jpg
# 4300TL83C04AK19P100022-01.jpg
# 4300TL83R30AC122100003-01.jpg
# 4300TL83Q1DAF1AK100018-01.jpg
# 4300TL83L0TAL161100011-01.jpg
# 4300TL83Q14AL105100003-01.jpg
# 4300TL83H1WAM15L100006-01.jpg
# 4300TL83T2AAS115100002-01.jpg
# 4300TL83N0RAE142100006-01.jpg
# 4300TL83R32AH16M100019-01.jpg
# 4300TL83L1CAW14L100004-01.jpg
# 4300TL83K2TAE1BL100013-01.jpg
# 4300TL83S2UBC10D100002-01.jpg
# 4300TL83J1AAH181100016-01.jpg
# 4300TL7CS36AE198100006-01.jpg
# 4300TL83R34AC18B100012-01.jpg
# 4300TL83K2HAM191100024-01.jpg
# 4300TL83S0EAP106100006-01.jpg
# 4300TL83Q0XAG167100006-01.jpg
# 4300TL83S18AV111100004-01.jpg
# 4300TL83S18AH197100029-01.jpg
# 4300TL83H3MAN15N100013-01.jpg
# 4300TL83S30AP144100011-01.jpg
# 4300TL83J1FAZ124100007-01.jpg
# 4300TL83M0JAC115100002-01.jpg
# 4300TL83K2QAE149100008-01.jpg
# 4300TL83Q0LAY1B3100018-01.jpg
# 4300TL83K0YAS137100007-01.jpg

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %%
# create result2 dir
import shutil

# img_path = "/home/kelly/Pictures/fastrcnn/8800_0302_100/demo"
# xml_path = "/home/kelly/Pictures/fastrcnn/8800_0302_100/result3/data"
# output_path = "/home/kelly/Pictures/fastrcnn/8800_0302_100/result3"

# for root, dirs, files in os.walk(xml_path):
#     for file in files:
#         shutil.move(os.path.join(root,file),os.path.join(output_path,"Annotations",file))
#         shutil.copy(os.path.join(img_path, root.split("/")[-1], file[:-4]+".jpg"),\
#                     os.path.join(output_path,"JPEGImages",file[:-4]+".jpg"))
#         shutil.copy(os.path.join(img_path, root.split("/")[-1], file[:-4]+".jpg"),\
#                     os.path.join(xml_path, root.split("/")[-1], file[:-4]+".jpg"))
# merge last dir
last_dir = "/home/kelly/Pictures/fastrcnn/8800_0302_100/result2"
now_dir = "/home/kelly/Pictures/fastrcnn/8800_0302_100/result3"
for root,dirs,files in os.walk(os.path.join(last_dir,"Annotations")):
    for file in files:
        print(file)
        shutil.copy(os.path.join(root,file),os.path.join(now_dir,"Annotations",file))
        root_tmp = os.path.join(*(root.split("/")[:-1]))
        shutil.copy(os.path.join('/'+root_tmp,"JPEGImages",file[:-4]+".jpg"),\
                    os.path.join(now_dir,"JPEGImages",file[:-4]+".jpg"))

# %% [markdown]
# # use the crop image to find no rec and save with xml
# #### xml is include x y xmax ymax

# %%
import os,cv2
import numpy as np
import xml.etree.cElementTree as ET
import shutil


crop_image_path = "/home/kelly/Pictures/defect/0308_work/2800_DBC_0928-0305"
no_rec_path = "/home/kelly/Pictures/defect/0308_work/no_redRec"
xml_path = "/home/kelly/Pictures/defect/0308_work/xml"

no_rec_arr = os.listdir(no_rec_path)

#8800TL7BQ2NBC138100001-01

for root,dirs,files in os.walk(crop_image_path):
    for file in files:
        print(file)
        if file in no_rec_arr:
            print("!!")
            # create xml
            oriImg = cv2.imread(os.path.join(no_rec_path,file[:-4]+".jpg"))
            if not os.path.exists(os.path.join("/home/kelly/Pictures/defect/0308_work/data",root.split('/')[-1])):
                os.mkdir(os.path.join("/home/kelly/Pictures/defect/0308_work/data",root.split('/')[-1]))
            shutil.copy(os.path.join(no_rec_path,file[:-4]+".jpg"), os.path.join("/home/kelly/Pictures/defect/0308_work/data",root.split('/')[-1],file[:-4]+".jpg"))
            cropImg = cv2.imread(os.path.join(root,file[:-4]+".jpg"))
            
            result = cv2.matchTemplate(oriImg, cropImg, cv2.TM_CCOEFF_NORMED) 
            x_and_y = np.unravel_index(result.argmax(),result.shape)
            print(x_and_y)
            tree = ET.parse('/home/kelly/Pictures/fastrcnn/8800_0307/result/Annotations/8800AAHFJABXD1A2100001-01.xml')
            tree_root = tree.getroot()
            change_dict = {"filename":"8800TL76B0TAM1BA100001-01","width":oriImg.shape[1],"height":oriImg.shape[0],"xmin":x_and_y[1],"ymin":x_and_y[0],\
                                           "xmax":x_and_y[1]+cropImg.shape[1],"ymax":x_and_y[0]+cropImg.shape[0],"name":root.split('/')[-1]}

            for key in change_dict.keys():
                for e in tree_root.iter(key):
                    e.text = str(change_dict[key])
                    tree.write(os.path.join(xml_path,file[:-4]+".xml"))
        else:
            print("the file doesn't exist")

# %% [markdown]
# ### -----------------------------------------------------------------------------------------

# %%
# find red rec and move to the data and delete xml
# PPP0 PC07 PF01 PF02
import os,shutil
base_path = "/msl/home/kelly08385/Pictures/Fast_defect/4300/ori"
des_path = "/msl/home/kelly08385/Pictures/Fast_defect/4300/rec"
# xml_path = "/home/kelly/Pictures/fastrcnn/2300_0322/result/Annotations"

for root,dirs,files in os.walk(base_path):
    for file in files:
        dir = root.split('/')[-1]
        if dir == "PS_R":
            cropImg = getImgInRedRect(os.path.join(root,file))
            if not cropImg is None:
                print(os.path.join(root,file))
                _despath = os.path.join(des_path,dir)
                mkdir(_despath)
    #             print(os.path.join(xml_path,file[:-4]+".xml"))
                shutil.move(os.path.join(root,file),os.path.join(_despath,file))
    #             os.remove(os.path.join(xml_path,file[:-4]+".xml"))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK0RAD1N4100012-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN3NAF171100014-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF0UAR1J1100014-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN04AD151100005-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CP1GAK181100008-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK26AQ137100004-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CR1CAC1Q2100016-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CL27AA172100008-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CS0DAB115100011-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF04AS1B4100017-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK3MAG172100004-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF33AY199100010-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CS35AC132100003-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN03AU1C7100009-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CL2DBA17A100008-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK21BC1R6100028-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK21BB1JA100015-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CU1YAN1H6100011-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CR1BAD1DA100013-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN1KAN14B100006-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK22AZ1N7100015-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CL3TAV101100001-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK0RBB102100001-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM25AS1MA100015-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN1NAT161100004-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM25AS1N4100016-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF3GAF1PA100015-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CR09AK19C100012-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM2KAU15A100005-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK22AZ199100007-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CE1CBA1E1100009-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CL3SBB1P5100018-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CU0TAE1G2100013-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CR1NAF1B5100009-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK26BB1LA100017-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CG05AS1AA100011-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CH1VAK1A1100007-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM38AS188100013-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CH1YAU1R9100020-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CE4JAF147100003-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CD40AR109100002-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN04AM1A2100007-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM23AN1K2100014-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CL27AF1Q1100017-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CR1NAR1Q1100016-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF33AV101100001-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK22AX1A7100009-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF33AH13A100003-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF3BAV1E6100013-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM3CAW147100007-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK22AZ1Q9100017-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN05AQ1NA100018-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM25AM1QA100019-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL83F19AS103100001-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CL26AB1M5100021-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CT21AG1M6100019-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM3CAD142100006-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CU1YBB1N1100016-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CU0TAN1BA100011-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CP14AM1H6100013-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF0WBB1E6100009-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN04AW106100006-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK26AP158100003-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK21BC1P6100019-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CJ01AM176100008-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CR2LAA192100008-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CK22BB1NA100018-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN04AN1BA100009-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CL3SAW1E9100010-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CM2NAZ18L100018-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CF0UAL1E2100010-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN04AS103100003-01.jpg
# /msl/home/kelly08385/Pictures/Fast_defect/4300/ori/PS_R/4300TL7CN04BA1N5100020-01.jpg

# %%
# all defect class to one class
# change xml object name to defect

source_xml_path = "/msl/home/kelly08385/Pictures/trained_defect/4300/Annotations"
des_xml_path = "/msl/home/kelly08385/Pictures/trained_defect/total_0416/Annotations"
source_img_path = "/msl/home/kelly08385/Pictures/trained_defect/4300/data"
des_img_path = "/msl/home/kelly08385/Pictures/trained_defect/total_0416/JPEGImages"
des_img_path2 = "/msl/home/kelly08385/Pictures/trained_defect/total_0416/data/1156"

for root,dirs,files in os.walk(source_img_path):
    for file in files:
        dir = root.split('/')[-1]
        mkdir(os.path.join(des_img_path2,dir))
        _source_xml_path = os.path.join(source_xml_path,file[:-4]+'.xml')
        if os.path.exists(_source_xml_path):
            tree = ET.parse(_source_xml_path)
            tree_root = tree.getroot()
            change_dict = {"name":'defect'}

            for key in change_dict.keys():
                for e in tree_root.iter(key):
                    e.text = str(change_dict[key])
                    tree.write(os.path.join(des_xml_path,file[:-4]+".xml"))
            shutil.copy(os.path.join(root,file),os.path.join(des_img_path,file))
            shutil.copy(os.path.join(root,file),os.path.join(des_img_path2,dir,file))
